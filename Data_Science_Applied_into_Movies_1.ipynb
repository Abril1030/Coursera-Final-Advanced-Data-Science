# %% [markdown]
# # <h1 align="center">Data Science applied to Movies Ratings</h1>
# # <h2 align="center">**By: Juan Carlos Abril Ramírez**</h2>
# # <h3 align="center">*Date: August xx of 2022*</h3>
#
# ---

# %% [markdown]
# *First, we import the neccesary libraries for data cleansing and ETL*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# *Now, we proceed to call the CSV file, stored in my Repository. Then, we visualize the first 5 rows of the newly created table*

# %%
imdb_movies = pd.read_csv("imdb_top_1000.csv")

imdb_movies.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# *We then check the number of rows (should be 1000, since it's a top 1000!) and columns (should be the same as displayed in the output above)*

# %%
imdb_movies.shape
# Out:
# (1000, 16)

# %% [markdown]
# *We then check the full info of the dataframe, to make a choice on what to remove or what to use. Notice that there's many lost or null values in some things*

# %%
imdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# *Now we can visualize the statistical description of every column*

# %%
imdb_movies.describe(include='all')
# Out:
#                                               Poster_Link Series_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMDFkYT...     Drishyam
# freq                                                    1            2
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# count           1000         899     1000   1000  1000.000000
# unique           100          16      140    202          NaN
# top             2014           U  100 min  Drama          NaN
# freq              32         234       23     85          NaN
# mean             NaN         NaN      NaN    NaN     7.949300
# std              NaN         NaN      NaN    NaN     0.275491
# min              NaN         NaN      NaN    NaN     7.600000
# 25%              NaN         NaN      NaN    NaN     7.700000
# 50%              NaN         NaN      NaN    NaN     7.900000
# 75%              NaN         NaN      NaN    NaN     8.100000
# max              NaN         NaN      NaN    NaN     9.300000
#
#                                                  Overview  Meta_score  \
# count                                                1000  843.000000
# unique                                               1000         NaN
# top     Two imprisoned men bond over a number of years...         NaN
# freq                                                    1         NaN
# mean                                                  NaN   77.971530
# std                                                   NaN   12.376099
# min                                                   NaN   28.000000
# 25%                                                   NaN   70.000000
# 50%                                                   NaN   79.000000
# 75%                                                   NaN   87.000000
# max                                                   NaN  100.000000
#
#                 Director      Star1        Star2         Star3          Star4  \
# count               1000       1000         1000          1000           1000
# unique               548        660          841           891            939
# top     Alfred Hitchcock  Tom Hanks  Emma Watson  Rupert Grint  Michael Caine
# freq                  14         12            7             5              4
# mean                 NaN        NaN          NaN           NaN            NaN
# std                  NaN        NaN          NaN           NaN            NaN
# min                  NaN        NaN          NaN           NaN            NaN
# 25%                  NaN        NaN          NaN           NaN            NaN
# 50%                  NaN        NaN          NaN           NaN            NaN
# 75%                  NaN        NaN          NaN           NaN            NaN
# max                  NaN        NaN          NaN           NaN            NaN
#
#          No_of_Votes      Gross
# count   1.000000e+03        831
# unique           NaN        823
# top              NaN  4,360,000
# freq             NaN          5
# mean    2.736929e+05        NaN
# std     3.273727e+05        NaN
# min     2.508800e+04        NaN
# 25%     5.552625e+04        NaN
# 50%     1.385485e+05        NaN
# 75%     3.741612e+05        NaN
# max     2.343110e+06        NaN

# %% [markdown]
# *We could use the Released Year column values as possibly one of the predictors, so we can cluster it into groups*

# %%
imdb_movies["Genre"].value_counts().to_frame()
# Out:
#                            Genre
# Drama                         85
# Drama, Romance                37
# Comedy, Drama                 35
# Comedy, Drama, Romance        31
# Action, Crime, Drama          30
# ...                          ...
# Adventure, Thriller            1
# Animation, Action, Sci-Fi      1
# Action, Crime, Comedy          1
# Animation, Crime, Mystery      1
# Adventure, Comedy, War         1
#
# [202 rows x 1 columns]

# %%
#unique_genres=pd.unique(imdb_movies["Genre"].str.split(", ", expand=True).stack())
#pd.DataFrame(unique_genres,columns=["Genre"])

imdb_movies['Genre']=imdb_movies['Genre'].str.split(', ')
Average_Score_per_Genre = (imdb_movies.explode('Genre')
        .groupby('Genre')[['Series_Title', 'IMDB_Rating']]
        .agg({'Series_Title':'size', 'IMDB_Rating':'mean'})
      )
print(Average_Score_per_Genre)
# Out:
#            Series_Title  IMDB_Rating
# Genre
# Action              189     7.948677
# Adventure           196     7.952041
# Animation            82     7.930488
# Biography           109     7.935780
# Comedy              233     7.903433
# Crime               209     7.954545
# Drama               724     7.959392
# Family               56     7.912500
# Fantasy              66     7.931818
# Film-Noir            19     7.989474
# History              56     7.953571
# Horror               32     7.887500
# Music                35     7.914286
# Musical              17     7.947059
# Mystery              99     7.967677
# Romance             125     7.925600
# Sci-Fi               67     7.977612
# Sport                19     7.926316
# Thriller            137     7.909489
# War                  51     8.013725
# Western              20     8.000000

# %%
imdb_movies_1=imdb_movies.explode('Genre')
imdb_movies_1
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# ..                                                 ...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime     Genre  \
# 0    The Shawshank Redemption          1994           A  142 min     Drama
# 1               The Godfather          1972           A  175 min     Crime
# 1               The Godfather          1972           A  175 min     Drama
# 2             The Dark Knight          2008          UA  152 min    Action
# 2             The Dark Knight          2008          UA  152 min     Crime
# ..                        ...           ...         ...      ...       ...
# 998                  Lifeboat          1944         NaN   97 min     Drama
# 998                  Lifeboat          1944         NaN   97 min       War
# 999              The 39 Steps          1935         NaN   86 min     Crime
# 999              The 39 Steps          1935         NaN   86 min   Mystery
# 999              The 39 Steps          1935         NaN   86 min  Thriller
#
#      IMDB_Rating                                           Overview  \
# 0            9.3  Two imprisoned men bond over a number of years...
# 1            9.2  An organized crime dynasty's aging patriarch t...
# 1            9.2  An organized crime dynasty's aging patriarch t...
# 2            9.0  When the menace known as the Joker wreaks havo...
# 2            9.0  When the menace known as the Joker wreaks havo...
# ..           ...                                                ...
# 998          7.6  Several survivors of a torpedoed merchant ship...
# 998          7.6  Several survivors of a torpedoed merchant ship...
# 999          7.6  A man in London tries to help a counter-espion...
# 999          7.6  A man in London tries to help a counter-espion...
# 999          7.6  A man in London tries to help a counter-espion...
#
#      Meta_score              Director              Star1              Star2  \
# 0          80.0        Frank Darabont        Tim Robbins     Morgan Freeman
# 1         100.0  Francis Ford Coppola      Marlon Brando          Al Pacino
# 1         100.0  Francis Ford Coppola      Marlon Brando          Al Pacino
# 2          84.0     Christopher Nolan     Christian Bale       Heath Ledger
# 2          84.0     Christopher Nolan     Christian Bale       Heath Ledger
# ..          ...                   ...                ...                ...
# 998        78.0      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 998        78.0      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999        93.0      Alfred Hitchcock       Robert Donat  Madeleine Carroll
# 999        93.0      Alfred Hitchcock       Robert Donat  Madeleine Carroll
# 999        93.0      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No_of_Votes        Gross
# 0        Bob Gunton  William Sadler      2343110   28,341,469
# 1        James Caan    Diane Keaton      1620367  134,966,411
# 1        James Caan    Diane Keaton      1620367  134,966,411
# 2     Aaron Eckhart   Michael Caine      2303232  534,858,444
# 2     Aaron Eckhart   Michael Caine      2303232  534,858,444
# ..              ...             ...          ...          ...
# 998   Walter Slezak  William Bendix        26471          NaN
# 998   Walter Slezak  William Bendix        26471          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
#
# [2541 rows x 16 columns]

# %% [markdown]
# *We now change one of the column titles to make it more concrete, from Series Title to Movie Title*

# %%
column_names = imdb_movies_1.columns.values
column_names[1] = "Movie Title"
imdb_movies_1.columns = column_names
imdb_movies_1
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# ..                                                 ...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                   Movie Title Released_Year Certificate  Runtime     Genre  \
# 0    The Shawshank Redemption          1994           A  142 min     Drama
# 1               The Godfather          1972           A  175 min     Crime
# 1               The Godfather          1972           A  175 min     Drama
# 2             The Dark Knight          2008          UA  152 min    Action
# 2             The Dark Knight          2008          UA  152 min     Crime
# ..                        ...           ...         ...      ...       ...
# 998                  Lifeboat          1944         NaN   97 min     Drama
# 998                  Lifeboat          1944         NaN   97 min       War
# 999              The 39 Steps          1935         NaN   86 min     Crime
# 999              The 39 Steps          1935         NaN   86 min   Mystery
# 999              The 39 Steps          1935         NaN   86 min  Thriller
#
#      IMDB_Rating                                           Overview  \
# 0            9.3  Two imprisoned men bond over a number of years...
# 1            9.2  An organized crime dynasty's aging patriarch t...
# 1            9.2  An organized crime dynasty's aging patriarch t...
# 2            9.0  When the menace known as the Joker wreaks havo...
# 2            9.0  When the menace known as the Joker wreaks havo...
# ..           ...                                                ...
# 998          7.6  Several survivors of a torpedoed merchant ship...
# 998          7.6  Several survivors of a torpedoed merchant ship...
# 999          7.6  A man in London tries to help a counter-espion...
# 999          7.6  A man in London tries to help a counter-espion...
# 999          7.6  A man in London tries to help a counter-espion...
#
#      Meta_score              Director              Star1              Star2  \
# 0          80.0        Frank Darabont        Tim Robbins     Morgan Freeman
# 1         100.0  Francis Ford Coppola      Marlon Brando          Al Pacino
# 1         100.0  Francis Ford Coppola      Marlon Brando          Al Pacino
# 2          84.0     Christopher Nolan     Christian Bale       Heath Ledger
# 2          84.0     Christopher Nolan     Christian Bale       Heath Ledger
# ..          ...                   ...                ...                ...
# 998        78.0      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 998        78.0      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999        93.0      Alfred Hitchcock       Robert Donat  Madeleine Carroll
# 999        93.0      Alfred Hitchcock       Robert Donat  Madeleine Carroll
# 999        93.0      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No_of_Votes        Gross
# 0        Bob Gunton  William Sadler      2343110   28,341,469
# 1        James Caan    Diane Keaton      1620367  134,966,411
# 1        James Caan    Diane Keaton      1620367  134,966,411
# 2     Aaron Eckhart   Michael Caine      2303232  534,858,444
# 2     Aaron Eckhart   Michael Caine      2303232  534,858,444
# ..              ...             ...          ...          ...
# 998   Walter Slezak  William Bendix        26471          NaN
# 998   Walter Slezak  William Bendix        26471          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
#
# [2541 rows x 16 columns]

# %% [markdown]
# *Now we clean all of the column names and remove the unneccesary columns that may not be relevant to pinpoint the goal*

# %%
imdb_movies_1.columns = imdb_movies_1.columns.str.replace("_", " ")
imdb_movies_2=imdb_movies_1.drop(["Poster Link", "Certificate", "Overview", "Meta score", "Gross"], axis=1)
imdb_movies_2
# Out:
#                   Movie Title Released Year  Runtime     Genre  IMDB Rating  \
# 0    The Shawshank Redemption          1994  142 min     Drama          9.3
# 1               The Godfather          1972  175 min     Crime          9.2
# 1               The Godfather          1972  175 min     Drama          9.2
# 2             The Dark Knight          2008  152 min    Action          9.0
# 2             The Dark Knight          2008  152 min     Crime          9.0
# ..                        ...           ...      ...       ...          ...
# 998                  Lifeboat          1944   97 min     Drama          7.6
# 998                  Lifeboat          1944   97 min       War          7.6
# 999              The 39 Steps          1935   86 min     Crime          7.6
# 999              The 39 Steps          1935   86 min   Mystery          7.6
# 999              The 39 Steps          1935   86 min  Thriller          7.6
#
#                  Director              Star1              Star2  \
# 0          Frank Darabont        Tim Robbins     Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 2       Christopher Nolan     Christian Bale       Heath Ledger
# 2       Christopher Nolan     Christian Bale       Heath Ledger
# ..                    ...                ...                ...
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No of Votes
# 0        Bob Gunton  William Sadler      2343110
# 1        James Caan    Diane Keaton      1620367
# 1        James Caan    Diane Keaton      1620367
# 2     Aaron Eckhart   Michael Caine      2303232
# 2     Aaron Eckhart   Michael Caine      2303232
# ..              ...             ...          ...
# 998   Walter Slezak  William Bendix        26471
# 998   Walter Slezak  William Bendix        26471
# 999  Lucie Mannheim  Godfrey Tearle        51853
# 999  Lucie Mannheim  Godfrey Tearle        51853
# 999  Lucie Mannheim  Godfrey Tearle        51853
#
# [2541 rows x 11 columns]

# %% [markdown]
# *Now we reuse the value_counts for the now splitted Genre column attributes, to determine the filtering point*

# %%
imdb_movies_2["Genre"].value_counts().to_frame()
# Out:
#            Genre
# Drama        724
# Comedy       233
# Crime        209
# Adventure    196
# Action       189
# Thriller     137
# Romance      125
# Biography    109
# Mystery       99
# Animation     82
# Sci-Fi        67
# Fantasy       66
# History       56
# Family        56
# War           51
# Music         35
# Horror        32
# Western       20
# Film-Noir     19
# Sport         19
# Musical       17

# %% [markdown]
# *We now filter the movies by it's genre count. If we want to determine how many movies tend to have higher scores, by removing genres with counts lower than 200, we can filter it using index values and sorting it to a new list*

# %%
Genre_count = imdb_movies_2["Genre"].value_counts()
new_Genre_count = Genre_count > 200

filtered_genres = list(np.array(Genre_count.index.values)[np.array(new_Genre_count)])

# %%
rows_before = imdb_movies_2.shape[0] # number of rows of original dataframe
print("Number of rows of original dataframe is {}.".format(rows_before))

imdb_movies_3 = imdb_movies_2.loc[imdb_movies_2['Genre'].isin(filtered_genres)]

rows_after = imdb_movies_3.shape[0] # number of rows of processed dataframe
print("Number of rows of processed dataframe is {}.".format(rows_after))

print("{} rows removed!".format(rows_before - rows_after))
# Out:
# Number of rows of original dataframe is 2541.
# Number of rows of processed dataframe is 1166.
# 1375 rows removed!

# %% [markdown]
# *Another filter we can use, to test the model, is that we only take movies that have IMDB Ratings higher than 8.0*

# %%
imdb_movies_4=imdb_movies_3[imdb_movies_3['IMDB Rating'] > 8.0]

# %%
rows_before = imdb_movies_3.shape[0] # number of rows of original dataframe
print("Number of rows of original dataframe is {}.".format(rows_before))

rows_after = imdb_movies_4.shape[0] # number of rows of processed dataframe
print("Number of rows of processed dataframe is {}.".format(rows_after))

print("{} rows removed!".format(rows_before - rows_after))
# Out:
# Number of rows of original dataframe is 1166.
# Number of rows of processed dataframe is 380.
# 786 rows removed!

# %% [markdown]
# *We now merge the new data set, to remove duplicates (I made that by grouping the genres), and now we have a very selective list of movies, with the genres and rating higher than average. Then, we organize the dataframe by descending scores, just for fun!*

# %%
imdb_movies_5 = imdb_movies_4.groupby(['Movie Title','Released Year','Runtime','IMDB Rating','Director','Star1','Star2','Star3','Star4','No of Votes'])['Genre'].apply(', '.join).reset_index()
imdb_movies_5.sort_values('IMDB Rating', ascending=False)
# Out:
#                      Movie Title Released Year  Runtime  IMDB Rating  \
# 245     The Shawshank Redemption          1994  142 min          9.3
# 226                The Godfather          1972  175 min          9.2
# 0                   12 Angry Men          1957   96 min          9.0
# 221              The Dark Knight          2008  152 min          9.0
# 227       The Godfather: Part II          1974  202 min          9.0
# ..                           ...           ...      ...          ...
# 162                           PK          2014  153 min          8.1
# 165                   Paper Moon          1973  102 min          8.1
# 166                 Paris, Texas          1984  145 min          8.1
# 56   Dilwale Dulhania Le Jayenge          1995  189 min          8.1
# 281  Ôkami kodomo no Ame to Yuki          2012  117 min          8.1
#
#                  Director               Star1             Star2  \
# 245        Frank Darabont         Tim Robbins    Morgan Freeman
# 226  Francis Ford Coppola       Marlon Brando         Al Pacino
# 0            Sidney Lumet         Henry Fonda       Lee J. Cobb
# 221     Christopher Nolan      Christian Bale      Heath Ledger
# 227  Francis Ford Coppola           Al Pacino    Robert De Niro
# ..                    ...                 ...               ...
# 162       Rajkumar Hirani          Aamir Khan    Anushka Sharma
# 165     Peter Bogdanovich         Ryan O'Neal      Tatum O'Neal
# 166           Wim Wenders  Harry Dean Stanton  Nastassja Kinski
# 56          Aditya Chopra      Shah Rukh Khan             Kajol
# 281         Mamoru Hosoda        Aoi Miyazaki       Takao Osawa
#
#               Star3           Star4  No of Votes                 Genre
# 245      Bob Gunton  William Sadler      2343110                 Drama
# 226      James Caan    Diane Keaton      1620367          Crime, Drama
# 0     Martin Balsam    John Fiedler       689845          Crime, Drama
# 221   Aaron Eckhart   Michael Caine      2303232          Crime, Drama
# 227   Robert Duvall    Diane Keaton      1129952          Crime, Drama
# ..              ...             ...          ...                   ...
# 162     Sanjay Dutt     Boman Irani       163061         Comedy, Drama
# 165   Madeline Kahn  John Hillerman        42285  Comedy, Crime, Drama
# 166  Dean Stockwell  Aurore Clément        91188                 Drama
# 56      Amrish Puri    Farida Jalal        63516                 Drama
# 281     Haru Kuroki   Yukito Nishii        38803                 Drama
#
# [282 rows x 11 columns]

# %%
imdb_movies_6 = imdb_movies_5.assign(Stars = lambda x: imdb_movies_5['Star1'] + ', ' + imdb_movies_5['Star2'] + ', ' + imdb_movies_5['Star3'] + ', ' + imdb_movies_5['Star4'])

# %%
imdb_movies_7=imdb_movies_6.drop(['Star1','Star2','Star3','Star4','No of Votes'], axis=1)
imdb_movies_7.sort_values('IMDB Rating', ascending=False)
# Out:
#                      Movie Title Released Year  Runtime  IMDB Rating  \
# 245     The Shawshank Redemption          1994  142 min          9.3
# 226                The Godfather          1972  175 min          9.2
# 0                   12 Angry Men          1957   96 min          9.0
# 221              The Dark Knight          2008  152 min          9.0
# 227       The Godfather: Part II          1974  202 min          9.0
# ..                           ...           ...      ...          ...
# 162                           PK          2014  153 min          8.1
# 165                   Paper Moon          1973  102 min          8.1
# 166                 Paris, Texas          1984  145 min          8.1
# 56   Dilwale Dulhania Le Jayenge          1995  189 min          8.1
# 281  Ôkami kodomo no Ame to Yuki          2012  117 min          8.1
#
#                  Director                 Genre  \
# 245        Frank Darabont                 Drama
# 226  Francis Ford Coppola          Crime, Drama
# 0            Sidney Lumet          Crime, Drama
# 221     Christopher Nolan          Crime, Drama
# 227  Francis Ford Coppola          Crime, Drama
# ..                    ...                   ...
# 162       Rajkumar Hirani         Comedy, Drama
# 165     Peter Bogdanovich  Comedy, Crime, Drama
# 166           Wim Wenders                 Drama
# 56          Aditya Chopra                 Drama
# 281         Mamoru Hosoda                 Drama
#
#                                                  Stars
# 245  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 226  Marlon Brando, Al Pacino, James Caan, Diane Ke...
# 0    Henry Fonda, Lee J. Cobb, Martin Balsam, John ...
# 221  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 227  Al Pacino, Robert De Niro, Robert Duvall, Dian...
# ..                                                 ...
# 162  Aamir Khan, Anushka Sharma, Sanjay Dutt, Boman...
# 165  Ryan O'Neal, Tatum O'Neal, Madeline Kahn, John...
# 166  Harry Dean Stanton, Nastassja Kinski, Dean Sto...
# 56    Shah Rukh Khan, Kajol, Amrish Puri, Farida Jalal
# 281  Aoi Miyazaki, Takao Osawa, Haru Kuroki, Yukito...
#
# [282 rows x 7 columns]

# %%
imdb_movies_7.describe(include='all')
# Out:
#        Movie Title Released Year  Runtime  IMDB Rating        Director  Genre  \
# count          282           282      282   282.000000             282    282
# unique         281            83      110          NaN             192      7
# top       Drishyam          2014  130 min          NaN  Akira Kurosawa  Drama
# freq             2            10       10          NaN               9    164
# mean           NaN           NaN      NaN     8.258156             NaN    NaN
# std            NaN           NaN      NaN     0.210796             NaN    NaN
# min            NaN           NaN      NaN     8.100000             NaN    NaN
# 25%            NaN           NaN      NaN     8.100000             NaN    NaN
# 50%            NaN           NaN      NaN     8.200000             NaN    NaN
# 75%            NaN           NaN      NaN     8.300000             NaN    NaN
# max            NaN           NaN      NaN     9.300000             NaN    NaN
#
#                                                     Stars
# count                                                 282
# unique                                                282
# top     Henry Fonda, Lee J. Cobb, Martin Balsam, John ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
imdb_movies_7.to_csv('imdb_filtered_dataframe.csv')
